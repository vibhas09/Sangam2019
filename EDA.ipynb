# %%
import pandas as pd
train = pd.read_csv('Train.csv')

# %%
train
# Out:
#                  date_time is_holiday  air_pollution_index  humidity  \
# 0      2012-10-02 09:00:00       None                  121        89
# 1      2012-10-02 10:00:00       None                  178        67
# 2      2012-10-02 11:00:00       None                  113        66
# 3      2012-10-02 12:00:00       None                   20        66
# 4      2012-10-02 13:00:00       None                  281        65
# 5      2012-10-02 14:00:00       None                   23        65
# 6      2012-10-02 15:00:00       None                  184        64
# 7      2012-10-02 16:00:00       None                  167        64
# 8      2012-10-02 17:00:00       None                  119        63
# 9      2012-10-02 18:00:00       None                  161        63
# 10     2012-10-02 19:00:00       None                  243        62
# 11     2012-10-02 20:00:00       None                  150        62
# 12     2012-10-02 21:00:00       None                  128        61
# ...

# %%
train.describe()
# Out:
#        air_pollution_index      humidity    wind_speed  wind_direction  \
# count         33750.000000  33750.000000  33750.000000    33750.000000
# mean            154.841422     71.209007      3.378193      199.471852
# std              83.735515     16.852248      2.055792       99.841088
# min              10.000000     13.000000      0.000000        0.000000
# 25%              83.000000     60.000000      2.000000      130.000000
# 50%             155.000000     72.000000      3.000000      200.000000
# 75%             228.000000     85.000000      5.000000      290.000000
# max             299.000000    100.000000     16.000000      360.000000
#
#        visibility_in_miles     dew_point   temperature      rain_p_h  \
# count         33750.000000  33750.000000  33750.000000  33750.000000
# mean              4.989748      4.989748    280.069587      0.448739
# std               2.570021      2.570021     13.415256     53.526500
# ...

# %%
train['traffic_volume'].median()
# Out:
# 3335.0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33750 entries, 0 to 33749
# Data columns (total 16 columns):
# date_time              33750 non-null object
# is_holiday             33750 non-null object
# air_pollution_index    33750 non-null int64
# humidity               33750 non-null int64
# wind_speed             33750 non-null int64
# wind_direction         33750 non-null int64
# visibility_in_miles    33750 non-null int64
# dew_point              33750 non-null int64
# temperature            33750 non-null float64
# rain_p_h               33750 non-null float64
# snow_p_h               33750 non-null float64
# clouds_all             33750 non-null int64
# weather_type           33750 non-null object
# weather_description    33750 non-null object
# traffic_volume         33750 non-null int64
# date_time_1            33750 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(8), object(4)
# memory usage: 4.1+ MB

# %%
train.groupby(['is_holiday'])['is_holiday'].count().index
# Out:
# Index(['Christmas Day', 'Columbus Day', 'Independence Day', 'Labor Day',
#        'Martin Luther King Jr Day', 'Memorial Day', 'New Years Day', 'None',
#        'State Fair', 'Thanksgiving Day', 'Veterans Day',
#        'Washingtons Birthday'],
#       dtype='object', name='is_holiday')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (10,5))
plt.barh(train.groupby(['is_holiday'])['is_holiday'].count().index,train.groupby(['is_holiday'])['traffic_volume'].mean())
plt.show()

# %%
plt.figure(figsize = (10,5))
plt.barh(train.groupby(['is_holiday'])['is_holiday'].count().index,train.groupby(['is_holiday'])['traffic_volume'].median())
plt.show()

# %%
train['traffic_volume'].plot.line(figsize = (100,15))

# %%
train['date_time'] = pd.to_datetime(train['date_time'])

# %%
train.index = train['date_time']

# %%
train
# Out:
#                               date_time is_holiday  air_pollution_index  \
# date_time
# 2012-10-02 09:00:00 2012-10-02 09:00:00       None                  121
# 2012-10-02 10:00:00 2012-10-02 10:00:00       None                  178
# 2012-10-02 11:00:00 2012-10-02 11:00:00       None                  113
# 2012-10-02 12:00:00 2012-10-02 12:00:00       None                   20
# 2012-10-02 13:00:00 2012-10-02 13:00:00       None                  281
# 2012-10-02 14:00:00 2012-10-02 14:00:00       None                   23
# 2012-10-02 15:00:00 2012-10-02 15:00:00       None                  184
# 2012-10-02 16:00:00 2012-10-02 16:00:00       None                  167
# 2012-10-02 17:00:00 2012-10-02 17:00:00       None                  119
# 2012-10-02 18:00:00 2012-10-02 18:00:00       None                  161
# 2012-10-02 19:00:00 2012-10-02 19:00:00       None                  243
# 2012-10-02 20:00:00 2012-10-02 20:00:00       None                  150
# ...

# %%
train.resample('Y')['traffic_volume'].sum().plot.bar()

# %%
train.resample('Y')['traffic_volume'].mean().plot.bar()

# %%
train.resample('M')['traffic_volume'].sum().plot.barh(figsize = (10,15))

# %%
train.resample('M')['traffic_volume'].mean().plot.barh(figsize = (5,15))

# %%
train.groupby(by = train.index.month)['traffic_volume'].sum().plot.bar()

# %%
train.groupby(by = train.index.month)['traffic_volume'].mean().plot.bar()

# %%
train.groupby(by = train.index.day)['traffic_volume'].sum().plot.bar()

# %%
train.groupby(by = train.index.day)['traffic_volume'].mean().plot.bar()

# %%
train['dayofweek'] = train.index.dayofweek

# %%
train.groupby(['dayofweek'])['traffic_volume'].sum().plot.bar()

# %%
train.groupby(['dayofweek'])['traffic_volume'].mean().plot.bar()

# %%
train.groupby(by = train.index.hour)['traffic_volume'].mean().plot.bar()

# %%
train.head()
# Out:
#                               date_time is_holiday  air_pollution_index  \
# date_time
# 2012-10-02 09:00:00 2012-10-02 09:00:00       None                  121
# 2012-10-02 10:00:00 2012-10-02 10:00:00       None                  178
# 2012-10-02 11:00:00 2012-10-02 11:00:00       None                  113
# 2012-10-02 12:00:00 2012-10-02 12:00:00       None                   20
# 2012-10-02 13:00:00 2012-10-02 13:00:00       None                  281
#
#                      humidity  wind_speed  wind_direction  \
# date_time
# 2012-10-02 09:00:00        89           2             329
# 2012-10-02 10:00:00        67           3             330
# 2012-10-02 11:00:00        66           3             329
# 2012-10-02 12:00:00        66           3             329
# 2012-10-02 13:00:00        65           3             329
#
#                      visibility_in_miles  dew_point  temperature  rain_p_h  \
# date_time
# ...

# %%
trainX = train

# %%
def is_holiday(x):
    if x == None:
        return 0
    else:
        return 1
    
trainX['is_holiday'] = trainX['is_holiday'].apply(is_holiday)

# %%
import seaborn as sns
sns.lineplot(data= train['air_pollution_index'])

# %%
train['air_pollution_index'].value_counts().sort_index().plot(figsize = (20,10))

# %%
train.groupby(['air_pollution_index'])['traffic_volume'].mean().sort_index().plot(figsize = (20,10))

# %%
train['humidity'].value_counts().sort_index()
# Out:
# 13        2
# 14        2
# 15        1
# 16        6
# 17        4
# 18        8
# 19       12
# 20       12
# 21       21
# 22       34
# 23       31
# 24       41
# 25       30
# 26       40
# 27       69
# 28       58
# 29       87
# 30       73
# 31       81
# 32       92
# 33      104
# 34      117
# 35       72
# 36      142
# 37      156
# 38      121
# 39      169
# 40      172
# 41      181
# 42      183
#        ...
# 71      616
# 72      728
# 73      801
# 74      839
# 75      550
# 76      672
# 77      753
# 78      754
# 79      712
# 80      761
# 81      585
# 82      655
# 83      558
# 84      482
# 85      824
# 86      902
# 87      836
# 88      692
# 89      317
# 90      320
# 91      307
# 92      761
# 93     1204
# 94      372
# 95      296
# 96      288
# 97      221
# 98      209
# 99      159
# 100     890
# Name: humidity, Length: 88, dtype: int64

# %%
train.groupby(['humidity'])['traffic_volume'].mean().sort_index().plot.bar(figsize = (20,10))

# %%
train['wind_speed'].value_counts()
# Out:
# 2     6599
# 3     6549
# 4     5238
# 1     5001
# 5     3863
# 6     2510
# 7     1345
# 0     1331
# 8      748
# 9      359
# 10     123
# 11      52
# 12      17
# 13      10
# 15       3
# 14       1
# 16       1
# Name: wind_speed, dtype: int64

# %%
train.groupby(['wind_speed'])['traffic_volume'].mean().sort_index().plot.bar(figsize = (20,10))

# %%
train['wind_direction'].value_counts()
# Out:
# 0      962
# 150    786
# 140    753
# 302    737
# 310    700
# 160    698
# 300    673
# 320    668
# 170    658
# 290    641
# 270    628
# 130    612
# 180    598
# 280    564
# 330    561
# 260    509
# 120    468
# 190    467
# 350    435
# 340    426
# 10     413
# 110    409
# 250    407
# 200    397
# 360    390
# 20     377
# 210    374
# 240    356
# 220    355
# 100    318
#       ...
# 67      20
# 27      20
# 56      20
# 55      20
# 74      19
# 59      19
# 38      19
# 6       19
# 46      18
# 72      18
# 78      18
# 49      18
# 44      18
# 42      18
# 37      17
# 2       17
# 12      17
# 16      16
# 64      16
# 357     15
# 18      15
# 36      15
# 62      15
# 358     15
# 65      14
# 29      14
# 66      13
# 1       11
# 89      10
# 7        9
# Name: wind_direction, Length: 361, dtype: int64

# %%
train.groupby(['wind_direction'])['traffic_volume'].mean().sort_index().plot.barh(figsize = (20,200))

# %%
train['visibility_in_miles'].value_counts()
# Out:
# 5    3863
# 6    3800
# 4    3765
# 3    3755
# 1    3738
# 7    3727
# 2    3725
# 8    3706
# 9    3671
# Name: visibility_in_miles, dtype: int64

# %%
train.groupby(['visibility_in_miles'])['traffic_volume'].mean().sort_index().plot.bar()

# %%
train['dew_point'].value_counts()
# Out:
# 5    3863
# 6    3800
# 4    3765
# 3    3755
# 1    3738
# 7    3727
# 2    3725
# 8    3706
# 9    3671
# Name: dew_point, dtype: int64

# %%
train.groupby(['dew_point'])['traffic_volume'].mean().sort_index().plot.bar()

# %%
train.head()
# Out:
#                               date_time  is_holiday  air_pollution_index  \
# date_time
# 2012-10-02 09:00:00 2012-10-02 09:00:00           1                  121
# 2012-10-02 10:00:00 2012-10-02 10:00:00           1                  178
# 2012-10-02 11:00:00 2012-10-02 11:00:00           1                  113
# 2012-10-02 12:00:00 2012-10-02 12:00:00           1                   20
# 2012-10-02 13:00:00 2012-10-02 13:00:00           1                  281
#
#                      humidity  wind_speed  wind_direction  \
# date_time
# 2012-10-02 09:00:00        89           2             329
# 2012-10-02 10:00:00        67           3             330
# 2012-10-02 11:00:00        66           3             329
# 2012-10-02 12:00:00        66           3             329
# 2012-10-02 13:00:00        65           3             329
#
#                      visibility_in_miles  dew_point  temperature  rain_p_h  \
# date_time
# ...

# %%
train['rain_p_h'].value_counts().sort_index()
# Out:
# 0.00       30996
# 0.25         679
# 0.26           2
# 0.27           5
# 0.28          19
# 0.29           4
# 0.30         119
# 0.31           2
# 0.32          12
# 0.33           1
# 0.34          16
# 0.35           5
# 0.36           6
# 0.37           1
# 0.38          84
# 0.40           8
# 0.41           4
# 0.42          15
# 0.43           7
# 0.44          18
# 0.45           1
# 0.46           2
# 0.47           9
# 0.48           5
# 0.50           2
# 0.51         241
# 0.52           7
# 0.53           5
# 0.54           6
# 0.55          11
#            ...
# 12.19          3
# 12.45          1
# 12.70          2
# 12.83          1
# 13.21          3
# 13.32          3
# 13.46          4
# 13.64          3
# 14.73          3
# 15.41          2
# 15.75          1
# 16.00          2
# 16.38          3
# 16.51          1
# 18.03          1
# 18.42          1
# 18.80          1
# 19.90          3
# 20.07          4
# 20.24          3
# 21.42          3
# ...

# %%
train.groupby(['rain_p_h'])['traffic_volume'].mean().sort_index().plot()

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize = (20,20))
ax.plot(train.groupby(['rain_p_h'])['traffic_volume'].mean().sort_index(), 'r')
ax.set_xlim([0,25])
plt.show()

# %%
train['snow_p_h'].value_counts().sort_index()
# Out:
# 0.00    33687
# 0.05       14
# 0.06       12
# 0.08        2
# 0.10        6
# 0.13        6
# 0.17        3
# 0.21        1
# 0.25        6
# 0.32        5
# 0.44        2
# 0.51        6
# Name: snow_p_h, dtype: int64

# %%
train.groupby(['snow_p_h'])['traffic_volume'].mean().sort_index().plot.bar()

# %%
train['weather_description'].value_counts()
# Out:
# sky is clear                           7524
# mist                                   4047
# overcast clouds                        3972
# broken clouds                          3379
# light rain                             2442
# scattered clouds                       2294
# Sky is Clear                           1709
# few clouds                             1568
# light snow                             1280
# moderate rain                          1105
# haze                                    902
# light intensity drizzle                 703
# heavy snow                              587
# fog                                     567
# drizzle                                 460
# proximity thunderstorm                  345
# heavy intensity rain                    311
# snow                                    190
# thunderstorm                             66
# proximity shower rain                    54
# thunderstorm with heavy rain             42
# ...

# %%
train.groupby(['weather_type'])['weather_description'].value_counts()
# Out:
# weather_type  weather_description
# Clear         sky is clear                           7524
#               Sky is Clear                           1709
# Clouds        overcast clouds                        3972
#               broken clouds                          3379
#               scattered clouds                       2294
#               few clouds                             1568
# Drizzle       light intensity drizzle                 703
#               drizzle                                 460
#               heavy intensity drizzle                  40
#               shower drizzle                            1
# Fog           fog                                     567
# Haze          haze                                    902
# Mist          mist                                   4047
# Rain          light rain                             2442
#               moderate rain                          1105
#               heavy intensity rain                    311
# ...

# %%
train.groupby(['weather_type', 'weather_description'])['traffic_volume'].mean()
# Out:
# weather_type  weather_description
# Clear         Sky is Clear                           3417.205968
#               sky is clear                           3026.460393
# Clouds        broken clouds                          3481.830719
#               few clouds                             3569.742347
#               overcast clouds                        3302.797080
#               scattered clouds                       3841.502616
# Drizzle       drizzle                                3041.732609
#               heavy intensity drizzle                3158.500000
#               light intensity drizzle                3309.857752
#               shower drizzle                         2010.000000
# Fog           fog                                    2740.603175
# Haze          haze                                   3638.919069
# Mist          mist                                   2943.952310
# Rain          freezing rain                          4314.000000
# ...
